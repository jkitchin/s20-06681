# %% [markdown]
# These are lecture notes from a mini course I taught on data science and machine learning in chemical engineering.
#
# ![img](./data-hydra.png)
#
# These are the official lectures from the class. I hope they work for you, but there may be links to files in a google drive that only CMU students can access. Let me know in an [issue](https://github.com/jkitchin/s20-06681/issues) if you find one.
#
# 1.  [Introduction](00-introduction/00-introduction.ipynb)
# 2.  [Using numpy](01-numpy/01-numpy.ipynb)
# 3.  [Interactive visualization with numpy and matplotlib](02-numpy-vis/02-numpy-vis.ipynb)
# 4.  [Introduction to Pandas](03-pandas-intro/03-pandas-intro.ipynb)
# 5.  [Intermediate Pandas](04-intermediate-pandas/04-intermediate-pandas.ipynb)
# 6.  [Pandas as a database](05-pandas-database/05-pandas-database.ipynb)
# 7.  [Introduction to linear regression with sklearn](06-linear-regression/06-linear-regression.ipynb)
# 8.  [Intermediate sklearn](07-intermediate-sklearn/07-intermediate-sklearn.ipynb)
# 9.  [Nonlinear models in sklearn](08-nonlinear-sklearn/08-nonlinear-sklearn.ipynb)
# 10. [Random Forest regression](09-random-forests/09-random-forests.ipynb)
#
# Good luck!
