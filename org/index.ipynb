# %% [markdown]
# These are lecture notes from a mini course I taught on data science and machine learning in chemical engineering.
#
# 1.  [Introduction](00-introduction.ipynb)
# 2.  [Using numpy](01-numpy.ipynb)
# 3.  [Interactive visualization with numpy and matplotlib](02-numpy-vis.ipynb)
# 4.  [Introduction to Pandas](03-pandas-intro.ipynb)
# 5.  [Intermediate Pandas](04-intermediate-pandas.ipynb)
# 6.  [Pandas as a database](05-pandas-database.ipynb)
